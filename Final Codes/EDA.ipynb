# %%
import numpy as np
import pandas as pd

# %%
train_val = pd.read_csv("train_values.csv")
train_labels = pd.read_csv("train_labels.csv")

# %%
train_val.describe()
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# count  2.606010e+05   260601.000000   260601.000000   260601.000000
# mean   5.256755e+05       13.900353      701.074685     6257.876148
# std    3.045450e+05        8.033617      412.710734     3646.369645
# min    4.000000e+00        0.000000        0.000000        0.000000
# 25%    2.611900e+05        7.000000      350.000000     3073.000000
# 50%    5.257570e+05       12.000000      702.000000     6270.000000
# 75%    7.897620e+05       21.000000     1050.000000     9412.000000
# max    1.052934e+06       30.000000     1427.000000    12567.000000
#
#        count_floors_pre_eq            age  area_percentage  height_percentage  \
# count        260601.000000  260601.000000    260601.000000      260601.000000
# mean              2.129723      26.535029         8.018051           5.434365
# std               0.727665      73.565937         4.392231           1.918418
# ...

# %%
train_labels.describe()
# Out:
#         building_id   damage_grade
# count  2.606010e+05  260601.000000
# mean   5.256755e+05       2.238272
# std    3.045450e+05       0.611814
# min    4.000000e+00       1.000000
# 25%    2.611900e+05       2.000000
# 50%    5.257570e+05       2.000000
# 75%    7.897620e+05       3.000000
# max    1.052934e+06       3.000000

# %%
train = pd.merge(train_val,train_labels,how="inner",on="building_id")
# print(train.select_dtypes(include="number").describe())
# train_numeric = train.select_dtypes(include="number")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260601 entries, 0 to 260600
# Data columns (total 40 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   building_id                             260601 non-null  int64
#  1   geo_level_1_id                          260601 non-null  int64
#  2   geo_level_2_id                          260601 non-null  int64
#  3   geo_level_3_id                          260601 non-null  int64
#  4   count_floors_pre_eq                     260601 non-null  int64
#  5   age                                     260601 non-null  int64
#  6   area_percentage                         260601 non-null  int64
#  7   height_percentage                       260601 non-null  int64
#  8   land_surface_condition                  260601 non-null  object
#  9   foundation_type                         260601 non-null  object
# ...

# %%
train.isnull().sum().sort_values(ascending=False)
# Out:
# building_id                               0
# geo_level_1_id                            0
# has_superstructure_bamboo                 0
# has_superstructure_rc_non_engineered      0
# has_superstructure_rc_engineered          0
# has_superstructure_other                  0
# legal_ownership_status                    0
# count_families                            0
# has_secondary_use                         0
# has_secondary_use_agriculture             0
# has_secondary_use_hotel                   0
# has_secondary_use_rental                  0
# has_secondary_use_institution             0
# has_secondary_use_school                  0
# has_secondary_use_industry                0
# has_secondary_use_health_post             0
# has_secondary_use_gov_office              0
# has_secondary_use_use_police              0
# has_secondary_use_other                   0
# has_superstructure_timber                 0
# has_superstructure_cement_mortar_brick    0
# ...

# %%
train.nunique().sort_values(ascending=False)
# Out:
# building_id                               260601
# geo_level_3_id                             11595
# geo_level_2_id                              1414
# area_percentage                               84
# age                                           42
# geo_level_1_id                                31
# height_percentage                             27
# count_families                                10
# plan_configuration                            10
# count_floors_pre_eq                            9
# foundation_type                                5
# ground_floor_type                              5
# legal_ownership_status                         4
# other_floor_type                               4
# position                                       4
# damage_grade                                   3
# roof_type                                      3
# land_surface_condition                         3
# has_superstructure_mud_mortar_stone            2
# ...

# %%
train[train.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [building_id, geo_level_1_id, geo_level_2_id, geo_level_3_id, count_floors_pre_eq, age, area_percentage, height_percentage, land_surface_condition, foundation_type, roof_type, ground_floor_type, other_floor_type, position, plan_configuration, has_superstructure_adobe_mud, has_superstructure_mud_mortar_stone, has_superstructure_stone_flag, has_superstructure_cement_mortar_stone, has_superstructure_mud_mortar_brick, has_superstructure_cement_mortar_brick, has_superstructure_timber, has_superstructure_bamboo, has_superstructure_rc_non_engineered, has_superstructure_rc_engineered, has_superstructure_other, legal_ownership_status, count_families, has_secondary_use, has_secondary_use_agriculture, has_secondary_use_hotel, has_secondary_use_rental, has_secondary_use_institution, has_secondary_use_school, has_secondary_use_industry, has_secondary_use_health_post, has_secondary_use_gov_office, has_secondary_use_use_police, has_secondary_use_other, damage_grade]
# ...

# %%
train[train.columns[train.nunique() <= 2]] = train[train.columns[train.nunique() <= 2]].astype("category")
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260601 entries, 0 to 260600
# Data columns (total 40 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   building_id                             260601 non-null  int64
#  1   geo_level_1_id                          260601 non-null  int64
#  2   geo_level_2_id                          260601 non-null  int64
#  3   geo_level_3_id                          260601 non-null  int64
#  4   count_floors_pre_eq                     260601 non-null  int64
#  5   age                                     260601 non-null  int64
#  6   area_percentage                         260601 non-null  int64
#  7   height_percentage                       260601 non-null  int64
#  8   land_surface_condition                  260601 non-null  object
#  9   foundation_type                         260601 non-null  object
# ...

# %%
print(train["plan_configuration"].unique())
print(train["position"].unique())
print(train["other_floor_type"].unique())
print(train["ground_floor_type"].unique())
print(train["land_surface_condition"].unique())
print(train["foundation_type"].unique())
print(train["roof_type"].unique())
print(train["legal_ownership_status"].unique())
print(train["count_families"].unique())
# Out:
# ['d' 'u' 's' 'q' 'm' 'c' 'a' 'n' 'f' 'o']
# ['t' 's' 'j' 'o']
# ['q' 'x' 'j' 's']
# ['f' 'x' 'v' 'z' 'm']
# ['t' 'o' 'n']
# ['r' 'w' 'i' 'u' 'h']
# ['n' 'q' 'x']
# ['v' 'a' 'r' 'w']
# [1 0 2 3 4 5 6 7 9 8]

# %%
train.dtypes.value_counts()
# Out:
# category    22
# int64       10
# object       8
# Name: count, dtype: int64

# %%
train_numeric = train.select_dtypes(include="number")
#subset = train.select_dtypes(include="number").columns.difference(["building_id"])
train_numeric = train_numeric.drop(['building_id'], axis=1)
corr_mat = train_numeric.corr()
corr_mat[corr_mat > 0.7]
# Out:
#                      geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# geo_level_1_id                  1.0             NaN             NaN
# geo_level_2_id                  NaN             1.0             NaN
# geo_level_3_id                  NaN             NaN             1.0
# count_floors_pre_eq             NaN             NaN             NaN
# age                             NaN             NaN             NaN
# area_percentage                 NaN             NaN             NaN
# height_percentage               NaN             NaN             NaN
# count_families                  NaN             NaN             NaN
# damage_grade                    NaN             NaN             NaN
#
#                      count_floors_pre_eq  age  area_percentage  \
# geo_level_1_id                       NaN  NaN              NaN
# geo_level_2_id                       NaN  NaN              NaN
# geo_level_3_id                       NaN  NaN              NaN
# ...

# %%
train["damage_grade"].value_counts()
# Out:
# damage_grade
# 2    148259
# 3     87218
# 1     25124
# Name: count, dtype: int64

# %%
train.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type  ... has_secondary_use_hotel  \
# 0                      t               r  ...                       0
# ...
